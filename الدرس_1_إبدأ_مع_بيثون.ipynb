# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamed-ali/mlar/blob/master/الدرس 1- إبدأ مع بيثون.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # <div dir="rtl">لماذا بيثون</div>
# <div dir="rtl">
# في السنوات الأخيرة, يعدّ بيثون (Python) من لغات البرمجة الأسرع إنتشارا حول العالم. يمكننا أن نرا تطوّر الإهتمام ببيثون بإستعمال
#     google trends
#     :
# </div>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div dir="rtl">
#     و في أخر إستقصاء إحصائي لعام 2019 على موقع ستاك أوفرفلو (stackoverflow) نرى أنّ بيثون قد حاز على مرتبة متقدّمة بين لغات البرمجة التيّ يحبّها و يستعملها المبرمجون المحترفون
#     (المصدر: https://insights.stackoverflow.com/survey/2019#technology )
# </div>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div dir="rtl">
#        هذا النجاح الملحوظ يحيل بأنّ تعلّم لغة البرمجة بيثون سيسهّل دخول المتعلّم إلي سوق الشغل.
# </div>
